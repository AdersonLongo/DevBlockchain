# %% [markdown]
# <a href="https://colab.research.google.com/github/AdersonLongo/DevBlockchain/blob/main/Exercicio_kNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPORTAR BIBLIOTECAS**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# Carregar a base de dados IRIS
iris = load_iris()
iris

# %%
# Criar um DataFrame a partir dos dados do Iris
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Dividir os dados em conjunto de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=65)

# %%
# Plotar gráfico de dispersão para a base de treinamento
cmap = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cmap)
plt.title("Base de Treinamento")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.show()

# %%
# Plotar gráfico de dispersão para a base de teste
plt.figure()
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cmap)
plt.title("Base de Teste")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.show()

# %%
# Criar o classificador kNN com k = 3
knn = KNeighborsClassifier(n_neighbors=6)

# %%
# Treinar o modelo com os dados de treinamento
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
# Fazer previsões no conjunto de teste
y_pred = knn.predict(X_test)

# %%
# Calcular a acurácia das previsões
accuracy = accuracy_score(y_test, y_pred)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 0.9333333333333333

# %%
# Fazer previsões no conjunto de teste
y_pred = knn.predict(X_test)

# %%
# Calcular a matriz de confusão
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  2,  9]])

# %%
# Plotar a matriz de confusão
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Matriz de Confusão")
plt.xlabel("Classe Predita")
plt.ylabel("Classe Real")
plt.show()

# %%
# Calcular a acurácia das previsões
accuracy = accuracy_score(y_test, y_pred)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 0.9

# %% [markdown]
# Reproduzir com a base *Breast Cancer Wisconsin (Diagnostic)* **negrito**

# %%
# Carregar a base de dados Breast Cancer Wisconsin (Diagnostic)
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
data

# %%
# Criar um DataFrame a partir dos dados do Breast Cancer
df = pd.DataFrame(data=data.data, columns=data.feature_names)
print(df.head())

# %%
# Dividir os dados em conjunto de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=65)

# %%
# Plotar gráfico de dispersão para a base de treinamento
cmap = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
plt.figure()
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cmap)
plt.title("Base de Treinamento")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.show()

# %%
# Plotar gráfico de dispersão para a base de teste
plt.figure()
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cmap)
plt.title("Base de Teste")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.show()

# %%
# Criar o classificador kNN com k = 3
knn = KNeighborsClassifier(n_neighbors=6)

# %%
# Treinar o modelo com os dados de treinamento
knn.fit(X_train, y_train)

# %%
# Fazer previsões no conjunto de teste
y_pred = knn.predict(X_test)

# %%
# Calcular a acurácia das previsões
accuracy = accuracy_score(y_test, y_pred)
print("Acurácia:", accuracy)

# %%
# Fazer previsões no conjunto de teste
y_pred = knn.predict(X_test)

# %%
# Calcular a matriz de confusão
cm = confusion_matrix(y_test, y_pred)
cm

# %%
# Plotar a matriz de confusão
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Matriz de Confusão")
plt.xlabel("Classe Predita")
plt.ylabel("Classe Real")
plt.show()
